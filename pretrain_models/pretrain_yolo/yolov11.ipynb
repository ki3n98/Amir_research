# %%
import os
import torch
import matplotlib.pyplot as plt
from ultralytics import YOLO
# %matplotlib inline


yolov11 = YOLO("yolo11n.pt")

data_dir = os.path.join("..","data", "mobile detection.v7i.yolov11", "data.yaml")

yolo_results = yolov11.train(data=data_dir, 
                             epochs=100, 
                             imgsz=640,
                             batch=32)
# Out:
# New https://pypi.org/project/ultralytics/8.3.199 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.195 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 9885MiB)
# ...

# %%
# from ultralytics import YOLO
# m = YOLO("path/to/best.pt")
yolov11.export(format="onnx", opset=12, dynamic=True, simplify=True)
yolov11.export(format="torchscript")
# Out:
# Ultralytics 8.3.195 🚀 Python-3.12.3 torch-2.8.0+cu128 CPU (Intel Core i7-10700K 3.80GHz)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/home/kien/Desktop/projects/Amir_research/pretrain_models/pretrain_yolo/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.19.0 opset 12...
# ONNX: slimming with onnxslim 0.1.67...
# ONNX: export success ✅ 1.8s, saved as '/home/kien/Desktop/projects/Amir_research/pretrain_models/pretrain_yolo/runs/detect/train2/weights/best.onnx' (10.0 MB)
#
# Export complete (2.0s)
# Results saved to /home/kien/Desktop/projects/Amir_research/pretrain_models/pretrain_yolo/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=/home/kien/Desktop/projects/Amir_research/pretrain_models/pretrain_yolo/runs/detect/train2/weights/best.onnx imgsz=640
# ...
