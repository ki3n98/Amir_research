# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO("yolo11n.yaml")

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11n.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="coco8.yaml", epochs=3)

# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model("https://ultralytics.com/images/bus.jpg")

# Export the model to ONNX format
success = model.export(format="onnx")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 9.2MB/s 0.6sss
# Ultralytics 8.3.189 🚀 Python-3.12.3 torch-2.8.0+cu126 CPU (AMD Ryzen 5 Microsoft Surface  Edition)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8/432.8KB 6.8MB/s 0.1s
# Unzipping /home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8.zip to /home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 5145.1files/s 0.0s
# Dataset download success ✅ (0.4s), saved to /home/kien/Desktop/projects/Amir_research/yolo/datasets
#
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1255.5±377.9 MB/s, size: 50.0 KB)
# train: Scanning /home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 431.8it/s 0.0s
# train: New cache created: /home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1191.0±276.2 MB/s, size: 54.0 KB)
# val: Scanning /home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1344.8it/s 0.0s
# val: New cache created: /home/kien/Desktop/projects/Amir_research/yolo/datasets/coco8/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3         0G      1.063      3.437      1.224         24        640: 100% ━━━━━━━━━━━━ 1/1 0.75it/s 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.8it/s 0.6s
#                    all          4         17      0.575       0.85      0.877      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3         0G      1.523      2.507      1.728         28        640: 100% ━━━━━━━━━━━━ 1/1 0.86it/s 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.1it/s 0.5s
#                    all          4         17      0.582       0.85      0.847      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3         0G      1.309      2.251      1.851         19        640: 100% ━━━━━━━━━━━━ 1/1 0.79it/s 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.2it/s 0.4s
#                    all          4         17      0.576       0.85      0.849      0.652
#
# 3 epochs completed in 0.002 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.189 🚀 Python-3.12.3 torch-2.8.0+cu126 CPU (AMD Ryzen 5 Microsoft Surface  Edition)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all          4         17      0.575       0.85      0.849      0.652
#                 person          3         10      0.589        0.6      0.588      0.293
#                    dog          1          1       0.55          1      0.995      0.796
#                  horse          1          2      0.523          1      0.995      0.674
#               elephant          1          2      0.364        0.5      0.524      0.259
#               umbrella          1          1       0.57          1      0.995      0.995
#           potted plant          1          1      0.851          1      0.995      0.895
# Speed: 2.0ms preprocess, 77.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       7 model = YOLO("yolo11n.pt")
#       9 # Train the model using the 'coco8.yaml' dataset for 3 epochs
# ---> 10 results = model.train(data="coco8.yaml", epochs=3)
#      12 # Evaluate the model's performance on the validation set
#      13 results = model.val()
#
# File ~/tf/lib/python3.12/site-packages/ultralytics/engine/model.py:799, in Model.train(self, trainer, **kwargs)
#     796     self.model = self.trainer.model
#     798 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799 self.trainer.train()
#     800 # Update model and cfg after training
#     801 if RANK in {-1, 0}:
#
# File ~/tf/lib/python3.12/site-packages/ultralytics/engine/trainer.py:229, in BaseTrainer.train(self)
#     226         ddp_cleanup(self, str(file))
#     228 else:
# --> 229     self._do_train(world_size)
#
# File ~/tf/lib/python3.12/site-packages/ultralytics/engine/trainer.py:499, in BaseTrainer._do_train(self, world_size)
#     497     self.final_eval()
#     498     if self.args.plots:
# --> 499         self.plot_metrics()
#     500     self.run_callbacks("on_train_end")
#     501 self._clear_memory()
#
# File ~/tf/lib/python3.12/site-packages/ultralytics/models/yolo/detect/train.py:199, in DetectionTrainer.plot_metrics(self)
#     197 def plot_metrics(self):
#     198     """Plot metrics from a CSV file."""
# --> 199     plot_results(file=self.csv, on_plot=self.on_plot)
#
# File ~/tf/lib/python3.12/site-packages/ultralytics/utils/__init__.py:371, in plt_settings.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     369 try:
#     370     with plt.rc_context(rcparams):
# --> 371         result = func(*args, **kwargs)
#     372 finally:
#     373     if switch:
#
# File ~/tf/lib/python3.12/site-packages/ultralytics/utils/plotting.py:874, in plot_results(file, dir, segment, pose, classify, on_plot)
#     872 import matplotlib.pyplot as plt  # scope for faster 'import ultralytics'
#     873 import polars as pl
# --> 874 from scipy.ndimage import gaussian_filter1d
#     876 save_dir = Path(file).parent if file else Path(dir)
#     877 if classify:
#
# File ~/tf/lib/python3.12/site-packages/scipy/ndimage/__init__.py:166
#     162 del _support_alternative_backends, _ndimage_api, _delegators  # noqa: F821
#     165 # Deprecated namespaces, to be removed in v2.0.0
# --> 166 from . import filters
#     167 from . import fourier
#     168 from . import interpolation
#
# File <frozen importlib._bootstrap>:471, in _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:316, in acquire(self)
#
# KeyboardInterrupt:
